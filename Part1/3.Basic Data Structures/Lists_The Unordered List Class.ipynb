# %% [markdown]
# # The Unordered List Class
# - Unordered list는 node의 집합으로 구성됨. 각 항목은 명시적 참조에 의해 연결됨.
# - 첫 번째 노드가 무엇인지 알고 있는 한, 각각의 항목은 다음 노드를 찾을 수 있다.
#
# - UnorderedList 클래스는 리스트의 첫 번째 노드에 대한 참조가 있어야 한다.

# %%
class Node:
    def __init__(self,initdata):
        self.data = initdata
        self.next = None

    def getData(self):
        return self.data

    def getNext(self):
        return self.next

    def setData(self,newdata):
        self.data = newdata

    def setNext(self,newnext):
        self.next = newnext

# %%
# Listing 2

class UnorderedList:

    def __init__(self):
        self.head = None
    
    def isEmpty(self):
        return self.head == None
    
    def add(self, item):
        temp = Node(item)
        temp.setNext(self.head)
        self.head = temp
    
    def size(self):
        current = self.head
        count = 0
        while current != None:
            count = count + 1
            current = current.getNext()

        return count
    
    def search(self,item):
        current = self.head
        found = False
        while current != None and not found:
            if current.getData() == item:
                found = True
            else:
                current = current.getNext()

        return found
    
    def remove(self,item):
        current = self.head
        previous = None
        found = False
        while not found:
            if current.getData() == item:
                found = True
            else:
                previous = current
                current = current.getNext()

        if previous == None:
            self.head = current.getNext()
        else:
            previous.setNext(current.getNext())

# %% [markdown]
# ## __init__( )

# %%
def __init__(self):
        self.head = None

# %%
mylist = UnorderedList()

# %% [markdown]
# 그림 5. Linkedlist 생성 모습
# - Node 클래스에서 말했듯, self.head = None

# %%
# Figure 05. Init Linkedlist
from IPython.display import Image
Image(filename='img/initlinkedlist.png')

# %% [markdown]
# ## isEmpty( )

# %%
def isEmpty(self):
    return self.head == None

# %% [markdown]
# - self.head == None
# - linked list 안에 node가 없으면 True, 있으면 False

# %% [markdown]
# ## add( )

# %%
def add(self, item):
    temp = Node(item) 
    temp.setNext(self.head)
    self.head = temp # self.head가 None이 아니게

# %% [markdown]
# - 링크드 리스트 구조는 우리에게 단 하나의 입구를 제공한다.
# - 단 하나의 입구 == 리스트의 헤드
# - 모든 노드는 헤드를 통해서만 접근 가능
# - 새로운 노드를 추가하기 가장 쉬운 자리는 헤드의 오른쪽이거나 리스트의 시작점이다.
# - 다른말로하면, 우리는 새로운 항목을 리스트의 첫 번째 아이템으로 만들거나 기존의 첫 번째 아이템과 연결 될 것이다

# %%
# Figure 06. Linkedlist
from IPython.display import Image
Image(filename='img/linkedlist.png')

# %%
mylist.add(31)
mylist.add(77)
mylist.add(17)
mylist.add(93)
mylist.add(26)
mylist.add(54)

# %% [markdown]
# ### ADD가 이뤄지는 과정

# %%
from IPython.display import Image
Image(filename='./img/addtohead.png')
# figure 07. Adding a New Node is a Two-Step Process

# %% [markdown]
# - 첫 번째로 추가된 31 == last Node
# - 끝으로 추가된 54 == first Node
# - 새로운 노드를 만들어 temp에 저장(add 메소드 line2).
# - Step 1. 새롭게 추가된 노드의 참조를 바로 직전에 추가된 노드로 연결.(add 메소드 line3)
# - Step 2. 리스트의 헤드의 참조를 새롭게 추가된 노드로 변경.(add 메소드 line4)

# %%
def add(self, item):
    temp = Node(item)
    temp.setNext(self.head) # Step 01. 새롭게 추가된 노드의 참조를 바로 직전에 추가된 노드로 연결.
    self.head = temp        # Step 02. 리스트의 헤드의 참조를 새롭게 추가된 노드로 변경.

# %% [markdown]
# ### 만약 스텝1과 2가 뒤바뀐다면?
# (figure 08 참조)
# 리스트의 헤드가 유일하게 외부에서 접근할 수 있는 지점이기에, 나머지 노드에 접근할 수 있는 방법이 더 이상 없다.

# %%
from IPython.display import Image
Image(filename='./img/wrongorder.png')
# figure 08. Result of Reversing the Order of the Two Steps

# %% [markdown]
# # Implement size, search and remove method!

# %% [markdown]
# ## What is a traversal??

# %% [markdown]
# - size, search, remove 메소드는 linked list traversal(이하 순회)이라는 기법에 기초하여 구현됨.
# - 순회란 각 노드를 한 번씩 읽어 보는(visiting) 과정.
# - 순회중에 여러 가지 작업을 할 수 있으며 일단 순회를 해야 어떤 처리라도 할 수 있다. 특정값을 가진 노드를 검색한다거나 노드 전체를 출력할 때는 head에서부터 링크를 따라 모든 노드를 방문해 봐야 한다. 연결 리스트는 연속된 메모리 공간에 노드들이 배치되어 있지 않으므로 링크를 따라 가면서 노드를 반복적으로 읽어보는 방법밖에 없다.

# %% [markdown]
# ## size( )

# %%
def size(self):
    current = self.head
    count = 0
    while current != None: # add()가 한 번도 이뤄지지 않았다면 current == None 
        count = count + 1
        current = current.getNext() # class Node의 getNext()

    return count

# %% [markdown]
# - 순회시, 각 노드마다 count를 하는 방식

# %%
from IPython.display import Image
Image(filename='img/traversal.png')
# figure 09. Traversing the Linked List from the Head to the End

# %% [markdown]
# ## search( )

# %%
def search(self,item):
    current = self.head
    found = False
    while current != None and not found:
        if current.getData() == item:
            found = True
        else:
            current = current.getNext()

    return found

# %% [markdown]
# - size()와 크게 다르지 않음.
# - 각 노드를 순회하며 찾을 item과 비교하는 방식

# %%
from IPython.display import Image
Image(filename='img/search.png')
# figure 09. Successful Search for the Value 17

# %% [markdown]
# ## remove( )

# %%
def remove(self,item):
    current = self.head
    previous = None
    found = False
    while not found:
        if current.getData() == item:
            found = True
        else:
            previous = current
            current = current.getNext()

    if previous == None: # 리스트의 첫 아이템을 지울 때 
        self.head = current.getNext()
    else:
        previous.setNext(current.getNext())

# %% [markdown]
# ### remove( ) 는 어떻게 이뤄지나요?
# - 지우기 원하는 아이템을 순회 방식을 통해 찾아야함. search()와 유사
# - found = True 일 때 current는 지워져야 할 노드
# - 만약 아이템의 값을 지우는 방식으로 접근한다면??
# - 값은 지워지겠지만, 노드의 수와 아이템의 수가 일치하지 않게 돼 문제.
# - 아이템을 갖고 있는 노드 전체를 지우는 방법
# - current의 링크를 변경 시키기!
# - Previous 노드의 링크를 after 노드에 연결
# - 그러나 (singly) linked list에서는 뒤로는 돌아갈 수 없다.
# - previous 객체에 current의 값을 할당하는 것으로 문제 해결
# - current.getData()가 찾는 아이템이 아닌 경우, previous, current 노드 둘 다 한 걸음 나아감.(previous가 먼저 움직임)

# %%
from IPython.display import Image
Image(filename='img/removeinit.png')
# Figure 11: Initial Values for the previous and current References

# %%
from IPython.display import Image
Image(filename='img/prevcurr.png')
# Figure 12: previous and current Move Down the List

# %% [markdown]
# ## 일반적인 remove( ) 과정
# - (figure 13 참조) 링크의 수정을 통해 node가 제거되는 것을 볼 수 있다.

# %% [markdown]
# ## 특수한 remove( ) 과정 - 지울 대상이 첫 번째 노드인 경우
# - current(self.head)가 리스트의 첫 번째 노드와 연결돼 있고,
# - previous == None 이면
# - head -> getNext()

# %%
from IPython.display import Image
Image(filename='img/remove.png')
# Figure 13: Removing an Item from the Middle of the List

# %%
from IPython.display import Image
Image(filename='img/remove2.png')
# Figure 14: Removing the First Node from the List
